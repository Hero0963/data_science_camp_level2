# %% [markdown]
# <a href="https://colab.research.google.com/github/Hero0963/data_science_camp_level2/blob/main/task03/dscamp_lv2_task03_hw02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #練習：我們發現在前一個練習中取得的資料只有 10 筆，也就是 Yahoo 奇摩電影「本週新片」頁面上呈現的資料。根據觀察後發現除了這 10 之外，還有更多資料會以分頁的方式呈現。除此之外，也能夠從「上映中」與「即將上映」的頁面中找到更多的電影類型。接下來這個練習，會希望你能夠除了單頁面的資料也可以收集到更多的資料回來。

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
 
urls = ["https://movies.yahoo.com.tw/movie_thisweek.html", "https://movies.yahoo.com.tw/movie_intheaters.html", "https://movies.yahoo.com.tw/movie_comingsoon.html"]
search_pages = 3

for url in urls:
    print(url)
    print()
    for i in range(1, search_pages + 1):
        print("page = ", i)
        new_tab_url = url + "?page=" + str(i)
        response = requests.get(url=new_tab_url)
        soup = BeautifulSoup(response.text, 'lxml')
        info_items = soup.find_all('div', 'release_info')
        movies_info = []
        for item in info_items:

            name= item.find('div', 'release_movie_name').a.text.strip()
            english_name = item.find('div', 'en').a.text.strip()
            release_time = item.find('div', 'release_movie_time').text.split('：')[-1].strip()
            
            expectation = ""
            expectation_info = item.find('div', 'leveltext')
            if expectation_info:
                expectation = item.find('div', 'leveltext').span.text.strip()

            movies_info.append([name, english_name, release_time, expectation])


        pd_movies_info = pd.DataFrame(movies_info, columns=['中文名稱','英文名稱','上映日期','期待度'])
        display(pd_movies_info)

        if pd_movies_info.empty:
            print("no data")
            print("no data")
            break


print("finished")
# Out:
# https://movies.yahoo.com.tw/movie_thisweek.html
#
# page =  1
#        中文名稱                       英文名稱        上映日期   期待度
# 0     玩命關頭X                     Fast X  2023-05-17   91%
# 1  我的2年妓女生涯                  La Maison  2023-05-19   88%
# 2    消失的紫斑蝶                             2023-05-19   86%
# 3       收陰機           Sound of Silence  2023-05-19  100%
# 4      烈火焚身                  Incendies  2023-05-19  100%
# 5     摘星甜點王            Sugar and Stars  2023-05-19  100%
# 6      非關男孩                About a Boy  2023-05-19  100%
# 7      擒慾女王  Queenie Classy Lusty Baby  2023-05-19  100%
# page =  2
# Empty DataFrame
# Columns: [中文名稱, 英文名稱, 上映日期, 期待度]
# Index: []
# no data
# no data
# https://movies.yahoo.com.tw/movie_intheaters.html
#
# page =  1
#         中文名稱                            英文名稱        上映日期   期待度
# 0     我的幸福婚約   As Long As We Both Shall Live  2023-05-12  100%
# 1       神鬼聖戰            The Devil Conspiracy  2023-05-12  100%
# 2         湯道                            Yudo  2023-05-12  100%
# 3       油麻菜籽                          Ah Fei  2023-05-12   89%
# 4       龍馬精神                         Ride On  2023-05-12   61%
# 5      正宗巨齒鯊                 The Black Demon  2023-05-12   98%
# 6     金之國水之國  Gold Kingdom and Water Kingdom  2023-05-12  100%
# 7      陰影下的她                      Next Sohee  2023-05-12  100%
# 8  Anne的多重恐懼                   Faces of Anne  2023-05-12  100%
# 9       玫瑰母親                  Mother and Son  2023-05-12  100%
# page =  2
#       中文名稱                    英文名稱        上映日期   期待度
# 0       炎日            Burning Days  2023-05-12  100%
# 1    開心鬼上身             Hello Ghost  2023-05-12  100%
# 2       邪厄           Home For Rent  2023-05-12  100%
# 3    揮灑心篇章              Maestro(s)  2023-05-05   80%
# 4  指尖上綻放的愛        A Mother's Touch  2023-05-05  100%
# 5    追殺代理人                Simulant  2023-05-05  100%
# 6    燃燒的玫瑰      The Colors of Fire  2023-05-05  100%
# 7    上流謀殺案  Invitation to a Murder  2023-05-05  100%
# 8      鬼噤聲            Tainted Soul  2023-05-05  100%
# 9     萊拉兄弟        Leila’s Brothers  2023-05-05  100%
# page =  3
#                      中文名稱                                         英文名稱  \
# 0                   神鬼第六感                                   The Others
# 1                  星際異攻隊3               Guardians of the Galaxy Vol. 3
# 2  王立宇宙軍～歐尼亞米斯之翼～：4K數位修復版  ROYAL SPACE FORCE – The Wings of Honnêamise
# 3                  梵蒂岡驅魔士                          The Pope’s Exorcist
# 4                    窄路微塵                              The Narrow Road
# 5                 離不開你的依賴                                   Dependence
# 6                   追兇12夜                        The Night of the 12th
# 7                     心之谷                         Whisper of the Heart
# 8                   愛情美樂地                                      Joyland
# 9                 扶桑花女孩之舞                             Hula Fulla Dance
#
#          上映日期   期待度
# 0  2023-05-05     0
# 1  2023-05-03   87%
# 2  2023-05-03   90%
# 3  2023-04-28   90%
# 4  2023-04-28   67%
# 5  2023-04-28  100%
# 6  2023-04-28  100%
# 7  2023-04-28  100%
# 8  2023-04-28   50%
# 9  2023-04-28  100%
# https://movies.yahoo.com.tw/movie_comingsoon.html
#
# page =  1
#            中文名稱                 英文名稱        上映日期   期待度
# 0          小美人魚       Little Mermaid  2023-05-25   24%
# 1          色局追兇                  360  2023-05-26   67%
# 2           厲嬰魂      The Unborn Soul  2023-05-26   80%
# 3         駭人骨娃娃   The Communion Girl  2023-05-26   75%
# 4        永遠的好麻吉             Dostojee  2023-05-26  100%
# 5         坎達哈行動             Kandahar  2023-05-26  100%
# 6          愛的密語            Safe Word  2023-05-26  100%
# 7        當男人戀愛時          Man in Love  2023-05-26   97%
# 8        燃起希望之火                Harka  2023-05-26  100%
# 9  禁忌的畫像：卡拉瓦喬之影  Caravaggio’S Shadow  2023-05-26  100%
# page =  2
#               中文名稱                                            英文名稱  \
# 0             烈火浩劫                                       The Blaze
# 1              鬼出櫃                                   The Boogeyman
# 2    名偵探神助理：黃金螺旋之謎                                         Nemesis
# 3             貞子DX                                       SADAKO DX
# 4              萊茵金                                       Rheingold
# 5            犯罪都市3                         The Roundup: No Way Out
# 6               爛人                                  The Worst Ones
# 7        安妮艾諾 超八時光                              Les années Super-8
# 8  米蘭昆德拉：從玩笑到無謂的盛宴  Milan Kundera: From The Joke to Insignificance
# 9             催眠狙擊                                        Hypnotic
#
#          上映日期   期待度
# 0  2023-06-02  100%
# 1  2023-06-02  100%
# 2  2023-06-02  100%
# 3  2023-06-02  100%
# 4  2023-06-02  100%
# 5  2023-06-02  100%
# 6  2023-06-02  100%
# 7  2023-06-02  100%
# 8  2023-06-02  100%
# 9  2023-06-02  100%
# page =  3
#              中文名稱                              英文名稱        上映日期   期待度
# 0       原罪犯 數位修復版                            Oldboy  2023-06-02  100%
# 1       變形金剛：萬獸崛起  Transformers: Rise of the Beasts  2023-06-07   95%
# 2     深夜加油站遇見蘇格拉底                  Peaceful Warrior  2023-06-09  100%
# 3  BLUE GIANT藍色巨星                        Blue Giant  2023-06-09  100%
# 4      我要復仇 數位修復版        Sympathy For Mr. Vengeance  2023-06-09  100%
# 5         阿諾是個模範生         Arnold Is A Model Student  2023-06-09
# 6             閃電俠                         The Flash  2023-06-14   83%
# 7              溟溟                                    2023-06-16   50%
# 8            大愚樂家                   Fool's Paradise  2023-06-16  100%
# 9           這裡沒有熊                          No Bears  2023-06-16  100%
# finished
